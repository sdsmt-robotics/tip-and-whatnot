# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(color_codes=True)

# %matplotlib inline

# %%
np.random.seed(sum(map(ord, 'distributions')))

x = np.random.normal(size=100)
sns.distplot(x)

# %% [markdown]
# This is a Markdown cell with $\LaTeX$

# %%
y = [1, 2, 3, 4, 4, 4, 4, 5, 5, 6]

sns.distplot(y)

# %%
print('hi')
# Out:
# hi
